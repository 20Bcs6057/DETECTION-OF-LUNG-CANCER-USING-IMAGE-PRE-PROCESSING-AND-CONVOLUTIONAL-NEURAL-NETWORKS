# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import cv2
import random
import imageio
import plotly.graph_objects as go
from collections import Counter

from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, recall_score, precision_score, classification_report, confusion_matrix, plot_confusion_matrix
from imblearn.over_sampling import SMOTE

import os
from keras.layers import Conv2D, MaxPooling2D, GlobalAveragePooling2D, BatchNormalization

from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation, Flatten

# %%
directory = 'C:/Users/Samik Bhatia/Desktop/Rohit/training cases'

categories = ['Bengin cases', 'Malignant cases', 'Normal cases']

# %%
size_data = {}
for i in categories:
    path = os.path.join(directory, i)
    class_num = categories.index(i)
    temp_dict = {}
    for file in os.listdir(path):
        filepath = os.path.join(path, file)
        height, width, channels = imageio.imread(filepath).shape
        if str(height) + ' x ' + str(width) in temp_dict:
            temp_dict[str(height) + ' x ' + str(width)] += 1 
        else:
            temp_dict[str(height) + ' x ' + str(width)] = 1
    
    size_data[i] = temp_dict
        
size_data
# Out:
# {'Bengin cases': {'512 x 512': 120},
#  'Malignant cases': {'512 x 512': 501,
#   '404 x 511': 1,
#   '512 x 801': 28,
#   '512 x 623': 31},
#  'Normal cases': {'512 x 512': 415, '331 x 506': 1}}

# %%
for i in categories:
    path = os.path.join(directory, i)
    class_num = categories.index(i)
    for file in os.listdir(path):
        filepath = os.path.join(path, file)
        print(i)
        img = cv2.imread(filepath, 0)
        plt.imshow(img)
        plt.show()
        break
# Out:
# Bengin cases
# Malignant cases
# Normal cases

# %%
img_size = 256
for i in categories:
    cnt, samples = 0, 3
    fig, ax = plt.subplots(samples, 3, figsize=(15, 15))
    fig.suptitle(i)
    
    path = os.path.join(directory, i)
    class_num = categories.index(i)
    for curr_cnt, file in enumerate(os.listdir(path)):
        filepath = os.path.join(path, file)
        img = cv2.imread(filepath, 0)
        
        img0 = cv2.resize(img, (img_size, img_size))
        
        img1 = cv2.GaussianBlur(img0, (5, 5), 0)
        
        ax[cnt, 0].imshow(img)
        ax[cnt, 1].imshow(img0)
        ax[cnt, 2].imshow(img1)
        cnt += 1
        if cnt == samples:
            break
        
plt.show()

# %%
data = []
img_size = 256

for i in categories:
    path = os.path.join(directory, i)
    class_num = categories.index(i)
    for file in os.listdir(path):
        filepath = os.path.join(path, file)
        img = cv2.imread(filepath, 0)
        # preprocess here
        img = cv2.resize(img, (img_size, img_size))
        data.append([img, class_num])
        
random.shuffle(data)

X, y = [], []
for feature, label in data:
    X.append(feature)
    y.append(label)
    
print('X length:', len(X))
print('y counts:', Counter(y))

# normalize
X = np.array(X).reshape(-1, img_size, img_size, 1)
X = X / 255.0
y = np.array(y)
# Out:
# X length: 1097
# y counts: Counter({1: 561, 2: 416, 0: 120})

# %%
X_train, X_valid, y_train, y_valid = train_test_split(X, y, random_state=10, stratify=y)

print(len(X_train), X_train.shape)
print(len(X_valid), X_valid.shape)
# Out:
# 822 (822, 256, 256, 1)
# 275 (275, 256, 256, 1)

# %%
print(Counter(y_train), Counter(y_valid))
# Out:
# Counter({1: 420, 2: 312, 0: 90}) Counter({1: 141, 2: 104, 0: 30})

# %%
print(len(X_train), X_train.shape)

X_train = X_train.reshape(X_train.shape[0], img_size*img_size*1)

print(len(X_train), X_train.shape)
# Out:
# 822 (822, 256, 256, 1)
# 822 (822, 65536)

# %%
print('Before SMOTE:', Counter(y_train))
smote = SMOTE()
X_train_sampled, y_train_sampled = smote.fit_resample(X_train, y_train)
print('After SMOTE:', Counter(y_train_sampled))
# Out:
# Before SMOTE: Counter({1: 420, 2: 312, 0: 90})
# After SMOTE: Counter({2: 420, 1: 420, 0: 420})

# %%
X_train = X_train.reshape(X_train.shape[0], img_size, img_size, 1)
X_train_sampled = X_train_sampled.reshape(X_train_sampled.shape[0], img_size, img_size, 1)

print(len(X_train), X_train.shape)
print(len(X_train_sampled), X_train_sampled.shape)
# Out:
# 822 (822, 256, 256, 1)
# 1260 (1260, 256, 256, 1)

# %%
model = Sequential()

model.add(Conv2D(64, (3, 3), input_shape=X_train.shape[1:]))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Flatten())
model.add(Dense(16))
model.add(Dense(3, activation='softmax'))

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 254, 254, 64)      640
#
#  activation (Activation)     (None, 254, 254, 64)      0
#
#  max_pooling2d (MaxPooling2D  (None, 127, 127, 64)     0
#  )
#
#  conv2d_1 (Conv2D)           (None, 125, 125, 64)      36928
#
#  max_pooling2d_1 (MaxPooling  (None, 62, 62, 64)       0
#  2D)
#
#  flatten (Flatten)           (None, 246016)            0
#
#  dense (Dense)               (None, 16)                3936272
#
#  dense_1 (Dense)             (None, 3)                 51
#
# =================================================================
# Total params: 3,973,891
# Trainable params: 3,973,891
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss='sparse_categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
history = model.fit(X_train_sampled, y_train_sampled, batch_size=8, epochs=10, validation_data=(X_valid, y_valid))
# Out:
# Epoch 1/10
# 158/158 [==============================] - 32s 198ms/step - loss: 0.5527 - accuracy: 0.8286 - val_loss: 0.1208 - val_accuracy: 0.9782
# Epoch 2/10
# 158/158 [==============================] - 35s 225ms/step - loss: 0.0277 - accuracy: 0.9937 - val_loss: 0.0453 - val_accuracy: 0.9782
# Epoch 3/10
# 158/158 [==============================] - 31s 197ms/step - loss: 0.0102 - accuracy: 0.9992 - val_loss: 0.0825 - val_accuracy: 0.9818
# Epoch 4/10
# 158/158 [==============================] - 31s 198ms/step - loss: 0.0260 - accuracy: 0.9937 - val_loss: 0.0495 - val_accuracy: 0.9891
# Epoch 5/10
# 158/158 [==============================] - 32s 201ms/step - loss: 4.8765e-04 - accuracy: 1.0000 - val_loss: 0.0689 - val_accuracy: 0.9927
# Epoch 6/10
# 158/158 [==============================] - 32s 201ms/step - loss: 2.0894e-04 - accuracy: 1.0000 - val_loss: 0.0566 - val_accuracy: 0.9964
# Epoch 7/10
# 158/158 [==============================] - 32s 201ms/step - loss: 1.3636e-04 - accuracy: 1.0000 - val_loss: 0.0601 - val_accuracy: 0.9964
# Epoch 8/10
# 158/158 [==============================] - 42s 268ms/step - loss: 8.5119e-05 - accuracy: 1.0000 - val_loss: 0.0674 - val_accuracy: 0.9927
# Epoch 9/10
# 158/158 [==============================] - 46s 292ms/step - loss: 6.2626e-05 - accuracy: 1.0000 - val_loss: 0.0606 - val_accuracy: 0.9964
# Epoch 10/10
# 158/158 [==============================] - 35s 220ms/step - loss: 5.7009e-05 - accuracy: 1.0000 - val_loss: 0.0632 - val_accuracy: 0.9927

# %%
model.save('my_model.h5')

# %%
y_pred = model.predict(X_valid, verbose=1)
y_pred_bool = np.argmax(y_pred, axis=1)

print(classification_report(y_valid, y_pred_bool))

print(confusion_matrix(y_true=y_valid, y_pred=y_pred_bool))
# Out:
# 9/9 [==============================] - 1s 157ms/step
#               precision    recall  f1-score   support
#
#            0       1.00      0.93      0.97        30
#            1       1.00      1.00      1.00       141
#            2       0.98      1.00      0.99       104
#
#     accuracy                           0.99       275
#    macro avg       0.99      0.98      0.99       275
# weighted avg       0.99      0.99      0.99       275
#
# [[ 28   0   2]
#  [  0 141   0]
#  [  0   0 104]]

# %%
plt.plot(history.history['accuracy'], label='Train')
plt.plot(history.history['val_accuracy'], label='Validation')
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend()
plt.show()

plt.plot(history.history['loss'], label='Train')
plt.plot(history.history['val_loss'], label='Validation')
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend()
plt.show()
